# %%
import numpy as np
import pandas as pd

import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Actual Ent Data

# %%
cons_df = pd.read_csv('conso-inf36-region.csv', sep=';')

# %%
cons_df
# Out:
#                          Horodate              Région  Code région  \
# 0       2022-03-31T23:30:00+02:00  Nouvelle Aquitaine           75
# 1       2022-03-31T23:30:00+02:00  Nouvelle Aquitaine           75
# 2       2022-03-31T23:30:00+02:00  Nouvelle Aquitaine           75
# 3       2022-03-31T23:30:00+02:00  Nouvelle Aquitaine           75
# 4       2022-03-31T23:30:00+02:00  Nouvelle Aquitaine           75
# ...                           ...                 ...          ...
# 354071  2022-01-01T00:00:00+01:00  Nouvelle Aquitaine           75
# 354072  2022-01-01T00:00:00+01:00  Nouvelle Aquitaine           75
# 354073  2022-01-01T00:00:00+01:00  Nouvelle Aquitaine           75
# 354074  2022-01-01T00:00:00+01:00  Nouvelle Aquitaine           75
# 354075  2022-01-01T00:00:00+01:00  Nouvelle Aquitaine           75
#
#                         Profil Plage de puissance souscrite  \
# 0              PRO1 (+ PRO1WE)              P8: ]24-30] kVA
# 1       PRO2 (+ PRO2WE + PRO6)          P0: Total <= 36 kVA
# 2                         PRO4              P1 : ]0-12] kVA
# 3                         PRO4              P5: ]12-15] kVA
# 4                         PRO5              P5: ]12-15] kVA
# ...                        ...                          ...
# 354071       RES11 (+ RES11WE)              P5: ]12-15] kVA
# 354072       RES11 (+ RES11WE)              P7: ]18-24] kVA
# 354073           RES2 (+ RES5)              P5: ]12-15] kVA
# 354074           RES2 (+ RES5)              P8: ]24-30] kVA
# 354075                  RES2WE          P0: Total <= 36 kVA
#
#         Nb points soutirage  Total énergie soutirée (Wh)  \
# 0                      5965                    6222225.0
# 1                     90689                   77781659.0
# 2                      1064                     192506.0
# 3                       212                      49785.0
# 4                       522                     924524.0
# ...                     ...                          ...
# 354071                13901                    7239675.0
# 354072                 1618                    1982859.0
# 354073                37216                   36667683.0
# 354074                 1856                    3243649.0
# 354075                22232                    6488097.0
#
#         Courbe Moyenne n°1 (Wh) Indice représentativité Courbe n°1 (%)  \
# 0                        1217.0                                     13
# 1                         973.0                                     16
# 2                         321.0                                     15
# 3                           NaN                                      S
# 4                        2096.0                                     39
# ...                         ...                                    ...
# 354071                    789.0                                      8
# 354072                   1465.0                                      7
# 354073                    811.0                                      8
# 354074                   1550.0                                      9
# 354075                    539.0                                     16
#
#         Courbe Moyenne n°2 (Wh) Indice représentativité Courbe n°2 (%)  \
# 0                        1428.0                                     13
# 1                         820.0                                     16
# 2                         126.0                                     14
# 3                           NaN                                      S
# 4                        1461.0                                     29
# ...                         ...                                    ...
# 354071                    564.0                                      8
# 354072                   1068.0                                      7
# 354073                    795.0                                      8
# 354074                   1283.0                                      8
# 354075                    470.0                                     16
#
#         Courbe Moyenne n°1 + n°2 (Wh)  \
# 0                              1321.0
# 1                               897.0
# 2                               226.0
# 3                                 NaN
# 4                              1822.0
# ...                               ...
# 354071                          677.0
# 354072                         1267.0
# 354073                          957.0
# 354074                         1421.0
# 354075                          791.0
#
#        Indice représentativité Courbe n°1 + n°2 (%)  Jour max du mois (0/1)  \
# 0                                                26                       0
# 1                                                32                       0
# 2                                                29                       0
# 3                                                 S                       0
# 4                                                69                       0
# ...                                             ...                     ...
# 354071                                           16                       0
# 354072                                           14                       0
# 354073                                           17                       0
# 354074                                           18                       0
# 354075                                           32                       0
#
#         Semaine max du mois (0/1)
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ...                           ...
# 354071                          0
# 354072                          0
# 354073                          0
# 354074                          0
# 354075                          0
#
# [354076 rows x 15 columns]

# %%
cons_df.drop(['Région', 'Code région', 'Plage de puissance souscrite', 'Nb points soutirage', 'Courbe Moyenne n°1 (Wh)', 'Indice représentativité Courbe n°1 (%)', 'Courbe Moyenne n°2 (Wh)', 'Indice représentativité Courbe n°2 (%)', 'Indice représentativité Courbe n°1 + n°2 (%)', 'Jour max du mois (0/1)', 'Semaine max du mois (0/1)', 'Courbe Moyenne n°1 + n°2 (Wh)'], axis='columns', inplace=True)
cons_df.dropna(inplace=True)
cons_df['Horodate'] = pd.to_datetime(cons_df['Horodate'].values, utc=True)
cons_df['Horodate'] = cons_df['Horodate'].dt.tz_localize(None)
cons_df = cons_df[cons_df['Profil'].str.contains("ENT")]
cons_df = cons_df.groupby('Horodate').sum().iloc[::-1]
cons_df.head(100)
# Out:
#                      Total énergie soutirée (Wh)
# Horodate
# 2022-03-31 21:30:00                    2496838.0
# 2022-03-31 21:00:00                    2496838.0
# 2022-03-31 20:30:00                    2496838.0
# 2022-03-31 20:00:00                    2496838.0
# 2022-03-31 19:30:00                    2496838.0
# ...                                          ...
# 2022-03-29 22:00:00                    2384608.0
# 2022-03-29 21:30:00                    2327092.0
# 2022-03-29 21:00:00                    2327092.0
# 2022-03-29 20:30:00                    2327092.0
# 2022-03-29 20:00:00                    2327092.0
#
# [100 rows x 1 columns]

# %% [markdown]
# # Load Forecasted Ent Data

# %%
fcst_df = pd.read_csv('sampleEntT12022.csv', sep=',')

# %%
fcst_df
# Out:
#                        Horodate  Total énergie soutirée (Wh)  \
# 0     2022-01-01T00:00:00+01:00                 2.466610e+06
# 1     2022-01-01T00:30:00+01:00                 2.473829e+06
# 2     2022-01-01T01:00:00+01:00                 2.487553e+06
# 3     2022-01-01T01:30:00+01:00                 2.496837e+06
# 4     2022-01-01T02:00:00+01:00                 2.497736e+06
# ...                         ...                          ...
# 4268  2022-03-30T22:00:00+01:00                 2.247825e+06
# 4269  2022-03-30T22:30:00+01:00                 2.246874e+06
# 4270  2022-03-30T23:00:00+01:00                 2.245444e+06
# 4271  2022-03-30T23:30:00+01:00                 2.244614e+06
# 4272  2022-03-31T00:00:00+01:00                 2.244845e+06
#
#       Nb points soutirage  Courbe Moyenne n°1 + n°2 (Wh) Profil
# 0                    1444                    1947.280600    ENT
# 1                    1444                    1935.073018    ENT
# 2                    1444                    1926.584128    ENT
# 3                    1444                    1922.857605    ENT
# 4                    1444                    1923.841501    ENT
# ...                   ...                            ...    ...
# 4268                 1444                    1683.531589    ENT
# 4269                 1444                    1668.392335    ENT
# 4270                 1444                    1651.145668    ENT
# 4271                 1444                    1633.206182    ENT
# 4272                 1444                    1615.974488    ENT
#
# [4273 rows x 5 columns]

# %%
fcst_df.drop(['Courbe Moyenne n°1 + n°2 (Wh)', 'Nb points soutirage', 'Profil'], axis='columns', inplace=True)
fcst_df['Horodate'] = pd.to_datetime(fcst_df['Horodate'].values, utc=True)
fcst_df['Horodate'] = fcst_df['Horodate'].dt.tz_localize(None)
fcst_df.set_index('Horodate', inplace=True)
fcst_df.head(100)
# Out:
#                      Total énergie soutirée (Wh)
# Horodate
# 2021-12-31 23:00:00                 2.466610e+06
# 2021-12-31 23:30:00                 2.473829e+06
# 2022-01-01 00:00:00                 2.487553e+06
# 2022-01-01 00:30:00                 2.496837e+06
# 2022-01-01 01:00:00                 2.497736e+06
# ...                                          ...
# 2022-01-02 22:30:00                 3.008211e+06
# 2022-01-02 23:00:00                 3.015408e+06
# 2022-01-02 23:30:00                 3.015487e+06
# 2022-01-03 00:00:00                 3.013352e+06
# 2022-01-03 00:30:00                 3.013198e+06
#
# [100 rows x 1 columns]

# %% [markdown]
# # Comparison between Actual and Forecasted Data

# %%
import plotly.graph_objects as go

# %%
# plot fcst_df and prod_df on the same plotly figure
fig = go.Figure()
fig.add_trace(go.Scatter(x=cons_df.index, y=cons_df['Total énergie soutirée (Wh)'], name='Actual'))
fig.add_trace(go.Scatter(x=fcst_df.index, y=fcst_df['Total énergie soutirée (Wh)'], name='Forecast'))
fig.update_layout(
    title='Actual and Forecasted Consumption',
    xaxis_title='Date',
    yaxis_title='Consumption (Wh)'
)
# Out:
# <div>                            <div id="198e9bf9-2ac0-46df-8514-47597c6e4165" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("198e9bf9-2ac0-46df-8514-47597c6e4165")) {                    Plotly.newPlot(                        "198e9bf9-2ac0-46df-8514-47597c6e4165",                        [{"name":"Actual","x":["2022-03-31T21:30:00","2022-03-31T21:00:00","2022-03-31T20:30:00","2022-03-31T20:00:00","2022-03-31T19:30:00","2022-03-31T19:00:00","2022-03-31T18:30:00","2022-03-31T18:00:00","2022-03-31T17:30:00","2022-03-31T17:00:00","2022-03-31T16:30:00","2022-03-31T16:00:00","2022-03-31T15:30:00","2022-03-31T15:00:00","2022-03-31T14:30:00","2022-03-31T14:00:00","2022-03-31T13:30:00","2022-03-31T13:00:00","2022-03-31T12:30:00","2022-03-31T12:00:00","2022-03-31T11:30:00","2022-03-31T11:00:00","2022-03-31T10:30:00","2022-03-31T10:00:00","2022-03-31T09:30:00","2022-03-31T09:00:00","2022-03-31T08:30:00","2022-03-31T08:00:00","2022-03-31T07:30:00","2022-03-31T07:00:00","2022-03-31T06:30:00","2022-03-31T06:00:00","2022-03-31T05:30:00","2022-03-31T05:00:00","2022-03-31T04:30:00","2022-03-31T04:00:00","2022-03-31T03:30:00","2022-03-31T03:00:00","2022-03-31T02:30:00","2022-03-31T02:00:00","2022-03-31T01:30:00","2022-03-31T01:00:00","2022-03-31T00:30:00","2022-03-31T00:00:00","2022-03-30T23:30:00","2022-03-30T23:00:00","2022-03-30T22:30:00","2022-03-30T22:00:00","2022-03-30T21:30:00","2022-03-30T21:00:00","2022-03-30T20:30:00","2022-03-30T20:00:00","2022-03-30T19:30:00","2022-03-30T19:00:00","2022-03-30T18:30:00","2022-03-30T18:00:00","2022-03-30T17:30:00","2022-03-30T17:00:00","2022-03-30T16:30:00","2022-03-30T16:00:00","2022-03-30T15:30:00","2022-03-30T15:00:00","2022-03-30T14:30:00","2022-03-30T14:00:00","2022-03-30T13:30:00","2022-03-30T13:00:00","2022-03-30T12:30:00","2022-03-30T12:00:00","2022-03-30T11:30:00","2022-03-30T11:00:00","2022-03-30T10:30:00","2022-03-30T10:00:00","2022-03-30T09:30:00","2022-03-30T09:00:00","2022-03-30T08:30:00","2022-03-30T08:00:00","2022-03-30T07:30:00","2022-03-30T07:00:00","2022-03-30T06:30:00","2022-03-30T06:00:00","2022-03-30T05:30:00","2022-03-30T05:00:00","2022-03-30T04:30:00","2022-03-30T04:00:00","2022-03-30T03:30:00","2022-03-30T03:00:00","2022-03-30T02:30:00","2022-03-30T02:00:00","2022-03-30T01:30:00","2022-03-30T01:00:00","2022-03-30T00:30:00","2022-03-30T00:00:00","2022-03-29T23:30:00","2022-03-29T23:00:00","2022-03-29T22:30:00","2022-03-29T22:00:00","2022-03-29T21:30:00","2022-03-29T21:00:00","2022-03-29T20:30:00","2022-03-29T20:00:00","2022-03-29T19:30:00","2022-03-29T19:00:00","2022-03-29T18:30:00","2022-03-29T18:00:00","2022-03-29T17:30:00","2022-03-29T17:00:00","2022-03-29T16:30:00","2022-03-29T16:00:00","2022-03-29T15:30:00","2022-03-29T15:00:00","2022-03-29T14:30:00","2022-03-29T14:00:00","2022-03-29T13:30:00","2022-03-29T13:00:00","2022-03-29T12:30:00","2022-03-29T12:00:00","2022-03-29T11:30:00","2022-03-29T11:00:00","2022-03-29T10:30:00","2022-03-29T10:00:00","2022-03-29T09:30:00","2022-03-29T09:00:00","2022-03-29T08:30:00","2022-03-29T08:00:00","2022-03-29T07:30:00","2022-03-29T07:00:00","2022-03-29T06:30:00","2022-03-29T06:00:00","2022-03-29T05:30:00","2022-03-29T05:00:00","2022-03-29T04:30:00","2022-03-29T04:00:00","2022-03-29T03:30:00","2022-03-29T03:00:00","2022-03-29T02:30:00","2022-03-29T02:00:00","2022-03-29T01:30:00","2022-03-29T01:00:00","2022-03-29T00:30:00","2022-03-29T00:00:00","2022-03-28T23:30:00","2022-03-28T23:00:00","2022-03-28T22:30:00","2022-03-28T22:00:00","2022-03-28T21:30:00","2022-03-28T21:00:00","2022-03-28T20:30:00","2022-03-28T20:00:00","2022-03-28T19:30:00","2022-03-28T19:00:00","2022-03-28T18:30:00","2022-03-28T18:00:00","2022-03-28T17:30:00","2022-03-28T17:00:00","2022-03-28T16:30:00","2022-03-28T16:00:00","2022-03-28T15: ...

# %%
# Remove records that don't have the same timestamp in both datasets
_cons_df = cons_df[cons_df.index.isin(fcst_df.index)]

# %%
_cons_df
# Out:
#                      Total énergie soutirée (Wh)
# Horodate
# 2022-03-30 23:00:00                    2496838.0
# 2022-03-30 22:30:00                    2496838.0
# 2022-03-30 22:00:00                    2496838.0
# 2022-03-30 21:30:00                    2384608.0
# 2022-03-30 21:00:00                    2384608.0
# ...                                          ...
# 2022-01-01 01:00:00                    2290959.0
# 2022-01-01 00:30:00                    2290959.0
# 2022-01-01 00:00:00                    2290959.0
# 2021-12-31 23:30:00                    2290959.0
# 2021-12-31 23:00:00                    2290959.0
#
# [4273 rows x 1 columns]

# %%
_fcst_df = fcst_df[fcst_df.index.isin(_cons_df.index)]

# %%
_fcst_df
# Out:
#                      Total énergie soutirée (Wh)
# Horodate
# 2021-12-31 23:00:00                 2.466610e+06
# 2021-12-31 23:30:00                 2.473829e+06
# 2022-01-01 00:00:00                 2.487553e+06
# 2022-01-01 00:30:00                 2.496837e+06
# 2022-01-01 01:00:00                 2.497736e+06
# ...                                          ...
# 2022-03-30 21:00:00                 2.247825e+06
# 2022-03-30 21:30:00                 2.246874e+06
# 2022-03-30 22:00:00                 2.245444e+06
# 2022-03-30 22:30:00                 2.244614e+06
# 2022-03-30 23:00:00                 2.244845e+06
#
# [4273 rows x 1 columns]

# %%
fcst_arr = _fcst_df['Total énergie soutirée (Wh)'].values
cons_arr = _cons_df['Total énergie soutirée (Wh)'].values

# %%
print("The mean percentage difference over the forecasted data is: {:.2%}".format(np.abs(np.mean((fcst_arr - cons_arr) / cons_arr))))
# Out:
# The mean percentage difference over the forecasted data is: 2.68%
